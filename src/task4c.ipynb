# %%
import skimage
import skimage.io
import skimage.transform
import skimage.filters
import os
import numpy as np
import utils
import matplotlib.pyplot as plt

# %%
def convolve_im(im: np.array,
                kernel: np.array,
                verbose=True):
    """ Convolves the image (im) with the spatial kernel (kernel),
        and returns the resulting image.

        "verbose" can be used for turning on/off visualization
        convolution
        
        Note: kernel can be of different shape than im.

    Args:
        im: np.array of shape [H, W]
        kernel: np.array of shape [K, K] 
        verbose: bool
    Returns:
        im: np.array of shape [H, W]
    """
    ### START YOUR CODE HERE ### (You can change anything inside this block)
    H, W = np.shape(im)
    K, _K = np.shape(kernel)
    C = 2       # Filter height
    D = 20      # Width of low-pass zone
    
    kernel_padded = np.zeros((H,W))
    kernel_padded[:K, :K] = kernel
    
    im_freq = np.fft.fft2(im)
    # kernel_freq = np.fft.fft2(kernel_padded)
    kernel_freq = np.ones((H,W), dtype=complex)
    kernel_freq[:C,:] = np.zeros((C,W))
    kernel_freq[-C:,:] = np.zeros((C,W))
    kernel_freq[C-1,:] = 0.5*np.zeros((1,W))
    kernel_freq[-C,:] = 0.5*np.zeros((1,W))
    kernel_freq[:C,:D] = np.ones((C,D))
    kernel_freq[:C,-D:] = np.ones((C,D))
    kernel_freq[-C:,:D] = np.ones((C,D))
    kernel_freq[-C:,-D:] = np.ones((C,D))
 
    conv_result_freq = np.zeros((H-K,W-K))
    # for i in range(H-K):
    #     for j in range(W-K):
    #         conv_result_freq[i,j] = kernel_freq * im_freq[i:i+K,j:j+K]
    conv_result_freq = kernel_freq * im_freq
    
    conv_result = np.fft.ifft2(conv_result_freq)

    if verbose:
        # Use plt.subplot to place two or more images beside eachother
        plt.figure(figsize=(20, 4))
        # plt.subplot(num_rows, num_cols, position (1-indexed))
        plt.subplot(1, 5, 1)
        plt.imshow(im, cmap="gray")
        plt.subplot(1, 5, 2) 
        # Visualize FFT
        plt.imshow(np.log(abs(np.fft.fftshift(im_freq)) + 1), cmap="gray")
        
        plt.subplot(1, 5, 3)
        # Visualize FFT kernel
        plt.imshow(np.log(abs(np.fft.fftshift(kernel_freq)) + 1), cmap="gray")
        
        plt.subplot(1, 5, 4)
        # Visualize filtered FFT image
        plt.imshow(np.log(abs(np.fft.fftshift(conv_result_freq)) + 1), cmap="gray")
         
        plt.subplot(1, 5, 5) 
        # Visualize filtered spatial image
        plt.imshow(np.real(conv_result), cmap="gray")
        
    ### END YOUR CODE HERE ###
    return conv_result

# %%
if __name__ == "__main__":
    # DO NOT CHANGE
    impath = os.path.join("images", "noisy_moon.png")
    im = utils.read_im(impath)

    ### START YOUR CODE HERE ### (You can change anything inside this block)
    verbose = True
    
    kernel = np.ones((5,5))
   
    
    # gaussian_kernel = np.array([
    #     [1, 4, 6, 4, 1],
    #     [4, 16, 24, 16, 4],
    #     [6, 24, 36, 24, 6],
    #     [4, 16, 24, 16, 4],
    #     [1, 4, 6, 4, 1],
    # ]) / 256
    im_filtered = convolve_im(im, kernel, verbose)
    
    
    ### END YOUR CODE HERE ###
    utils.save_im("moon_filtered.png", utils.normalize(im_filtered))
# Out:
# Saving image to: image_processed\moon_filtered.png
